# %% [markdown]
# # CVAE Demo

# %% [markdown]
# In this notebook I will show how to download model, functions and checkpoint and how to generate new digits on your own. The model we use was trained on 10 epochs and has latent space size of 80.

# %%
import sys
sys.path.append('../')

# %%
from models import CVAE
import utils
import torch

# %%
input_size = 784  
hidden_size = 250
latent_size = 80
num_of_classes = 10

# %%
model = CVAE(input_size, hidden_size, latent_size, num_of_classes)

model.load_state_dict(torch.load('model.pth', map_location='cpu'))

model.eval();

# %% [markdown]
# ## Samples

# %%
utils.plot(model, 10, 2, 5, 10);
